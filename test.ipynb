# %%
import or_suite

# %%
env = or_suite.envs.ambulance.ambulance_graph.AmbulanceGraphEnvironment()
agent = or_suite.agents.ambulance.stable.stableAgent(5)

dictionary = {'seed': 1, 'epFreq' : 1, 'targetPath': './tmp.csv', 'deBug' : True, 'nEps': 1000, 'recFreq' : 10, 'numIters' : 5, 'epLen': 5}

exp = or_suite.experiment.Experiment(env, agent, dictionary)
exp.run()
# Out:
# **************************************************
# Running experiment
# **************************************************
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [1]
# action : [1]
# final state: [0]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [0]
# action : [0]
# state : [1]
# action : [1]
# state : [1]
# action : [1]
# final state: [2]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [3]
# action : [3]
# final state: [0]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# final state: [0]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [3]
# action : [3]
# state : [1]
# action : [1]
# state : [2]
# action : [2]
# final state: [3]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [0]
# action : [0]
# state : [0]
# action : [0]
# state : [0]
# action : [0]
# final state: [3]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [1]
# action : [1]
# state : [3]
# action : [3]
# state : [2]
# action : [2]
# final state: [2]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [0]
# action : [0]
# final state: [3]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [3]
# action : [3]
# final state: [0]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [3]
# action : [3]
# state : [1]
# action : [1]
# state : [1]
# action : [1]
# final state: [0]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [1]
# action : [1]
# final state: [1]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [2]
# action : [2]
# final state: [2]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [1]
# action : [1]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# final state: [0]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# final state: [2]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [0]
# action : [0]
# state : [0]
# action : [0]
# state : [3]
# action : [3]
# final state: [1]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [3]
# action : [3]
# state : [1]
# action : [1]
# state : [3]
# action : [3]
# final state: [2]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [1]
# action : [1]
# final state: [1]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [1]
# action : [1]
# state : [3]
# action : [3]
# state : [2]
# action : [2]
# final state: [2]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [3]
# action : [3]
# state : [1]
# action : [1]
# state : [2]
# action : [2]
# final state: [1]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [3]
# action : [3]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# final state: [2]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [1]
# action : [1]
# final state: [3]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [3]
# action : [3]
# state : [2]
# action : [2]
# final state: [3]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [0]
# action : [0]
# state : [3]
# action : [3]
# state : [2]
# action : [2]
# final state: [0]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [3]
# action : [3]
# state : [3]
# action : [3]
# state : [2]
# action : [2]
# final state: [0]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [0]
# action : [0]
# state : [0]
# action : [0]
# state : [0]
# action : [0]
# final state: [3]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [0]
# action : [0]
# final state: [1]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# final state: [3]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [3]
# action : [3]
# state : [1]
# action : [1]
# state : [3]
# action : [3]
# final state: [2]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [0]
# action : [0]
# state : [0]
# action : [0]
# final state: [0]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [0]
# action : [0]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# final state: [0]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [3]
# action : [3]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# final state: [1]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# final state: [3]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [1]
# action : [1]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# final state: [0]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [0]
# action : [0]
# state : [1]
# action : [1]
# state : [2]
# action : [2]
# final state: [2]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [3]
# action : [3]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# final state: [2]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [0]
# action : [0]
# final state: [1]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [3]
# action : [3]
# state : [0]
# action : [0]
# final state: [1]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [0]
# action : [0]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# final state: [3]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [0]
# action : [0]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# final state: [3]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [0]
# action : [0]
# state : [0]
# action : [0]
# state : [2]
# action : [2]
# final state: [3]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [2]
# action : [2]
# final state: [1]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# final state: [3]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [3]
# action : [3]
# state : [0]
# action : [0]
# state : [0]
# action : [0]
# final state: [0]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [3]
# action : [3]
# state : [3]
# action : [3]
# final state: [0]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [1]
# action : [1]
# state : [0]
# action : [0]
# state : [3]
# action : [3]
# final state: [1]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [3]
# action : [3]
# final state: [3]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [1]
# action : [1]
# final state: [1]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# final state: [3]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [3]
# action : [3]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# final state: [3]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [1]
# action : [1]
# state : [2]
# action : [2]
# final state: [3]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [3]
# action : [3]
# state : [1]
# action : [1]
# state : [3]
# action : [3]
# final state: [2]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# final state: [2]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [3]
# action : [3]
# state : [3]
# action : [3]
# state : [2]
# action : [2]
# final state: [3]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [1]
# action : [1]
# final state: [1]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [1]
# action : [1]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# final state: [3]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [1]
# action : [1]
# state : [1]
# action : [1]
# final state: [3]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [3]
# action : [3]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# final state: [1]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [2]
# action : [2]
# final state: [2]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# final state: [1]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [1]
# action : [1]
# state : [0]
# action : [0]
# state : [3]
# action : [3]
# final state: [0]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [3]
# action : [3]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# final state: [0]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [1]
# action : [1]
# state : [0]
# action : [0]
# state : [2]
# action : [2]
# final state: [1]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [3]
# action : [3]
# state : [1]
# action : [1]
# state : [0]
# action : [0]
# final state: [0]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [0]
# action : [0]
# final state: [3]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [0]
# action : [0]
# final state: [2]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [0]
# action : [0]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# final state: [2]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [3]
# action : [3]
# state : [0]
# action : [0]
# state : [2]
# action : [2]
# final state: [3]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [1]
# action : [1]
# state : [3]
# action : [3]
# state : [3]
# action : [3]
# final state: [2]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [3]
# action : [3]
# state : [3]
# action : [3]
# state : [3]
# action : [3]
# final state: [0]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# final state: [0]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [1]
# action : [1]
# final state: [2]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [3]
# action : [3]
# state : [1]
# action : [1]
# state : [3]
# action : [3]
# final state: [3]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [0]
# action : [0]
# state : [3]
# action : [3]
# state : [2]
# action : [2]
# final state: [3]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# final state: [0]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [0]
# action : [0]
# state : [0]
# action : [0]
# state : [2]
# action : [2]
# final state: [0]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [3]
# action : [3]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# final state: [0]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [0]
# action : [0]
# final state: [0]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [3]
# action : [3]
# state : [1]
# action : [1]
# state : [0]
# action : [0]
# final state: [2]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [3]
# action : [3]
# state : [1]
# action : [1]
# state : [0]
# action : [0]
# final state: [2]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [1]
# action : [1]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# final state: [2]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [3]
# action : [3]
# state : [0]
# action : [0]
# state : [2]
# action : [2]
# final state: [1]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [0]
# action : [0]
# state : [1]
# action : [1]
# state : [0]
# action : [0]
# final state: [1]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [2]
# action : [2]
# final state: [3]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [3]
# action : [3]
# state : [1]
# action : [1]
# state : [3]
# action : [3]
# final state: [2]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [0]
# action : [0]
# state : [0]
# action : [0]
# state : [0]
# action : [0]
# final state: [1]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [0]
# action : [0]
# state : [3]
# action : [3]
# state : [1]
# action : [1]
# final state: [2]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [1]
# action : [1]
# state : [1]
# action : [1]
# state : [1]
# action : [1]
# final state: [3]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [3]
# action : [3]
# state : [0]
# action : [0]
# state : [3]
# action : [3]
# final state: [0]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# final state: [3]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [3]
# action : [3]
# state : [3]
# action : [3]
# state : [0]
# action : [0]
# final state: [0]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [3]
# action : [3]
# final state: [2]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [1]
# action : [1]
# state : [0]
# action : [0]
# final state: [0]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [3]
# action : [3]
# state : [0]
# action : [0]
# state : [1]
# action : [1]
# final state: [3]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [3]
# action : [3]
# state : [1]
# action : [1]
# state : [2]
# action : [2]
# final state: [1]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [1]
# action : [1]
# state : [1]
# action : [1]
# state : [2]
# action : [2]
# final state: [3]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [0]
# action : [0]
# final state: [2]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [3]
# action : [3]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# final state: [1]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [0]
# action : [0]
# state : [2]
# action : [2]
# final state: [1]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [1]
# action : [1]
# state : [0]
# action : [0]
# final state: [1]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [3]
# action : [3]
# state : [3]
# action : [3]
# state : [3]
# action : [3]
# final state: [0]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [0]
# action : [0]
# state : [1]
# action : [1]
# state : [0]
# action : [0]
# final state: [2]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [3]
# action : [3]
# state : [0]
# action : [0]
# state : [2]
# action : [2]
# final state: [0]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [0]
# action : [0]
# state : [0]
# action : [0]
# final state: [2]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [2]
# action : [2]
# final state: [3]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [3]
# action : [3]
# final state: [2]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [0]
# action : [0]
# state : [0]
# action : [0]
# state : [1]
# action : [1]
# final state: [1]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [0]
# action : [0]
# state : [3]
# action : [3]
# state : [3]
# action : [3]
# final state: [3]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [0]
# action : [0]
# final state: [1]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [1]
# action : [1]
# final state: [0]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [3]
# action : [3]
# state : [1]
# action : [1]
# state : [3]
# action : [3]
# final state: [0]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [1]
# action : [1]
# final state: [0]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# final state: [0]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [0]
# action : [0]
# final state: [2]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [3]
# action : [3]
# state : [2]
# action : [2]
# final state: [0]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [3]
# action : [3]
# state : [3]
# action : [3]
# state : [2]
# action : [2]
# final state: [2]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# final state: [1]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [0]
# action : [0]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# final state: [3]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [3]
# action : [3]
# state : [1]
# action : [1]
# state : [0]
# action : [0]
# final state: [3]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# final state: [0]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [0]
# action : [0]
# state : [1]
# action : [1]
# state : [0]
# action : [0]
# final state: [0]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [0]
# action : [0]
# state : [0]
# action : [0]
# final state: [0]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# final state: [3]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [3]
# action : [3]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# final state: [0]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [0]
# action : [0]
# state : [0]
# action : [0]
# state : [1]
# action : [1]
# final state: [1]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [2]
# action : [2]
# final state: [3]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# final state: [2]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [1]
# action : [1]
# final state: [3]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [3]
# action : [3]
# state : [0]
# action : [0]
# state : [1]
# action : [1]
# final state: [1]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [3]
# action : [3]
# state : [1]
# action : [1]
# state : [2]
# action : [2]
# final state: [1]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [0]
# action : [0]
# state : [0]
# action : [0]
# state : [2]
# action : [2]
# final state: [1]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [0]
# action : [0]
# state : [3]
# action : [3]
# state : [0]
# action : [0]
# final state: [3]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [3]
# action : [3]
# final state: [0]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [2]
# action : [2]
# final state: [0]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [3]
# action : [3]
# final state: [0]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [3]
# action : [3]
# final state: [2]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [1]
# action : [1]
# state : [0]
# action : [0]
# state : [3]
# action : [3]
# final state: [3]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# final state: [1]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [3]
# action : [3]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# final state: [2]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [3]
# action : [3]
# state : [3]
# action : [3]
# state : [0]
# action : [0]
# final state: [0]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [1]
# action : [1]
# state : [3]
# action : [3]
# state : [2]
# action : [2]
# final state: [1]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [1]
# action : [1]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# final state: [1]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [3]
# action : [3]
# state : [1]
# action : [1]
# state : [1]
# action : [1]
# final state: [2]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [1]
# action : [1]
# state : [1]
# action : [1]
# state : [2]
# action : [2]
# final state: [3]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [3]
# action : [3]
# state : [1]
# action : [1]
# state : [2]
# action : [2]
# final state: [0]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [3]
# action : [3]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# final state: [2]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [3]
# action : [3]
# state : [0]
# action : [0]
# state : [2]
# action : [2]
# final state: [3]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [3]
# action : [3]
# state : [1]
# action : [1]
# final state: [2]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# final state: [0]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [0]
# action : [0]
# state : [1]
# action : [1]
# state : [3]
# action : [3]
# final state: [0]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [3]
# action : [3]
# state : [1]
# action : [1]
# state : [1]
# action : [1]
# final state: [3]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [0]
# action : [0]
# state : [3]
# action : [3]
# state : [3]
# action : [3]
# final state: [1]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [1]
# action : [1]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# final state: [2]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [3]
# action : [3]
# state : [1]
# action : [1]
# state : [0]
# action : [0]
# final state: [0]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# final state: [2]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [1]
# action : [1]
# final state: [2]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [1]
# action : [1]
# state : [0]
# action : [0]
# state : [1]
# action : [1]
# final state: [0]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [3]
# action : [3]
# state : [1]
# action : [1]
# state : [3]
# action : [3]
# final state: [2]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [3]
# action : [3]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# final state: [3]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [1]
# action : [1]
# state : [1]
# action : [1]
# state : [2]
# action : [2]
# final state: [1]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [1]
# action : [1]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# final state: [3]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [0]
# action : [0]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# final state: [1]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [1]
# action : [1]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# final state: [0]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [1]
# action : [1]
# state : [3]
# action : [3]
# state : [1]
# action : [1]
# final state: [3]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [1]
# action : [1]
# state : [0]
# action : [0]
# state : [2]
# action : [2]
# final state: [2]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# final state: [1]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [1]
# action : [1]
# state : [0]
# action : [0]
# state : [2]
# action : [2]
# final state: [2]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [0]
# action : [0]
# final state: [2]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [0]
# action : [0]
# state : [1]
# action : [1]
# state : [1]
# action : [1]
# final state: [1]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [1]
# action : [1]
# state : [1]
# action : [1]
# state : [3]
# action : [3]
# final state: [3]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [2]
# action : [2]
# final state: [1]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# final state: [1]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [3]
# action : [3]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# final state: [2]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [1]
# action : [1]
# state : [2]
# action : [2]
# final state: [3]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [0]
# action : [0]
# final state: [3]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [0]
# action : [0]
# state : [1]
# action : [1]
# state : [0]
# action : [0]
# final state: [2]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [1]
# action : [1]
# state : [0]
# action : [0]
# state : [2]
# action : [2]
# final state: [2]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [0]
# action : [0]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# final state: [3]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [2]
# action : [2]
# final state: [1]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [1]
# action : [1]
# state : [1]
# action : [1]
# state : [1]
# action : [1]
# final state: [3]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [3]
# action : [3]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# final state: [1]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [3]
# action : [3]
# state : [0]
# action : [0]
# state : [3]
# action : [3]
# final state: [2]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [3]
# action : [3]
# state : [0]
# action : [0]
# state : [2]
# action : [2]
# final state: [0]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# final state: [3]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [1]
# action : [1]
# final state: [2]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [1]
# action : [1]
# state : [0]
# action : [0]
# state : [2]
# action : [2]
# final state: [1]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [3]
# action : [3]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# final state: [1]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [1]
# action : [1]
# state : [0]
# action : [0]
# state : [1]
# action : [1]
# final state: [2]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [0]
# action : [0]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# final state: [3]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [0]
# action : [0]
# state : [1]
# action : [1]
# state : [3]
# action : [3]
# final state: [0]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [1]
# action : [1]
# state : [0]
# action : [0]
# state : [0]
# action : [0]
# final state: [1]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [0]
# action : [0]
# final state: [0]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [1]
# action : [1]
# final state: [2]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [3]
# action : [3]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# final state: [0]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [1]
# action : [1]
# state : [1]
# action : [1]
# state : [3]
# action : [3]
# final state: [1]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [1]
# action : [1]
# state : [3]
# action : [3]
# final state: [1]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [1]
# action : [1]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# final state: [2]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [0]
# action : [0]
# state : [3]
# action : [3]
# state : [0]
# action : [0]
# final state: [1]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [3]
# action : [3]
# final state: [3]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [1]
# action : [1]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# final state: [2]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [1]
# action : [1]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# final state: [3]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [3]
# action : [3]
# state : [3]
# action : [3]
# state : [3]
# action : [3]
# final state: [1]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [0]
# action : [0]
# state : [1]
# action : [1]
# state : [0]
# action : [0]
# final state: [2]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [3]
# action : [3]
# state : [2]
# action : [2]
# final state: [0]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [0]
# action : [0]
# state : [1]
# action : [1]
# state : [0]
# action : [0]
# final state: [2]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [3]
# action : [3]
# final state: [1]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [3]
# action : [3]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# final state: [3]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [0]
# action : [0]
# state : [0]
# action : [0]
# state : [1]
# action : [1]
# final state: [3]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [1]
# action : [1]
# state : [0]
# action : [0]
# state : [3]
# action : [3]
# final state: [3]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [1]
# action : [1]
# state : [0]
# action : [0]
# state : [3]
# action : [3]
# final state: [3]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [1]
# action : [1]
# state : [3]
# action : [3]
# final state: [1]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [3]
# action : [3]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# final state: [3]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# final state: [2]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [0]
# action : [0]
# state : [0]
# action : [0]
# state : [3]
# action : [3]
# final state: [2]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [1]
# action : [1]
# state : [3]
# action : [3]
# final state: [1]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [3]
# action : [3]
# state : [0]
# action : [0]
# state : [3]
# action : [3]
# final state: [3]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# final state: [3]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [3]
# action : [3]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# final state: [0]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [0]
# action : [0]
# state : [0]
# action : [0]
# final state: [3]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [1]
# action : [1]
# state : [2]
# action : [2]
# final state: [2]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [3]
# action : [3]
# state : [3]
# action : [3]
# final state: [2]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [3]
# action : [3]
# state : [0]
# action : [0]
# state : [1]
# action : [1]
# final state: [3]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# final state: [3]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [0]
# action : [0]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# final state: [0]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [0]
# action : [0]
# state : [3]
# action : [3]
# final state: [0]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [0]
# action : [0]
# state : [3]
# action : [3]
# state : [2]
# action : [2]
# final state: [1]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [2]
# action : [2]
# final state: [1]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [1]
# action : [1]
# state : [0]
# action : [0]
# state : [2]
# action : [2]
# final state: [2]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [3]
# action : [3]
# state : [3]
# action : [3]
# state : [3]
# action : [3]
# final state: [3]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [1]
# action : [1]
# state : [1]
# action : [1]
# state : [2]
# action : [2]
# final state: [1]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# final state: [0]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [3]
# action : [3]
# state : [3]
# action : [3]
# state : [0]
# action : [0]
# final state: [0]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [1]
# action : [1]
# state : [3]
# action : [3]
# state : [2]
# action : [2]
# final state: [3]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [0]
# action : [0]
# state : [0]
# action : [0]
# state : [1]
# action : [1]
# final state: [0]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# final state: [0]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [1]
# action : [1]
# state : [0]
# action : [0]
# state : [0]
# action : [0]
# final state: [2]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [3]
# action : [3]
# state : [1]
# action : [1]
# final state: [3]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [2]
# action : [2]
# final state: [3]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [3]
# action : [3]
# state : [3]
# action : [3]
# state : [1]
# action : [1]
# final state: [2]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [0]
# action : [0]
# state : [3]
# action : [3]
# state : [0]
# action : [0]
# final state: [3]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [0]
# action : [0]
# state : [2]
# action : [2]
# final state: [3]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [2]
# action : [2]
# final state: [0]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [1]
# action : [1]
# state : [3]
# action : [3]
# state : [1]
# action : [1]
# final state: [3]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [0]
# action : [0]
# state : [1]
# action : [1]
# final state: [0]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [3]
# action : [3]
# state : [3]
# action : [3]
# final state: [0]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [1]
# action : [1]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# final state: [1]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [1]
# action : [1]
# state : [3]
# action : [3]
# state : [0]
# action : [0]
# final state: [3]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [3]
# action : [3]
# final state: [0]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [3]
# action : [3]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# final state: [0]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [0]
# action : [0]
# state : [0]
# action : [0]
# state : [3]
# action : [3]
# final state: [3]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [3]
# action : [3]
# state : [1]
# action : [1]
# final state: [1]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [3]
# action : [3]
# state : [1]
# action : [1]
# state : [1]
# action : [1]
# final state: [1]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [1]
# action : [1]
# state : [1]
# action : [1]
# state : [2]
# action : [2]
# final state: [0]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [3]
# action : [3]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# final state: [0]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [0]
# action : [0]
# final state: [3]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [3]
# action : [3]
# state : [1]
# action : [1]
# state : [2]
# action : [2]
# final state: [1]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [0]
# action : [0]
# state : [0]
# action : [0]
# state : [0]
# action : [0]
# final state: [1]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# final state: [2]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [0]
# action : [0]
# state : [0]
# action : [0]
# final state: [3]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [3]
# action : [3]
# state : [1]
# action : [1]
# state : [3]
# action : [3]
# final state: [2]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [1]
# action : [1]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# final state: [0]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# final state: [1]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [3]
# action : [3]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# final state: [2]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [0]
# action : [0]
# state : [1]
# action : [1]
# state : [1]
# action : [1]
# final state: [0]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# final state: [2]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [3]
# action : [3]
# state : [0]
# action : [0]
# final state: [1]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [3]
# action : [3]
# state : [0]
# action : [0]
# state : [2]
# action : [2]
# final state: [0]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [1]
# action : [1]
# final state: [2]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# final state: [2]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# final state: [2]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [1]
# action : [1]
# final state: [2]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [3]
# action : [3]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# final state: [1]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [0]
# action : [0]
# state : [2]
# action : [2]
# final state: [3]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [0]
# action : [0]
# state : [1]
# action : [1]
# final state: [3]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [3]
# action : [3]
# final state: [3]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [0]
# action : [0]
# state : [0]
# action : [0]
# state : [0]
# action : [0]
# final state: [0]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [0]
# action : [0]
# state : [3]
# action : [3]
# state : [2]
# action : [2]
# final state: [1]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [1]
# action : [1]
# state : [1]
# action : [1]
# state : [3]
# action : [3]
# final state: [2]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [1]
# action : [1]
# state : [1]
# action : [1]
# state : [0]
# action : [0]
# final state: [3]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [1]
# action : [1]
# state : [3]
# action : [3]
# state : [1]
# action : [1]
# final state: [1]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [3]
# action : [3]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# final state: [3]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# final state: [2]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [3]
# action : [3]
# state : [1]
# action : [1]
# state : [0]
# action : [0]
# final state: [0]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [3]
# action : [3]
# state : [3]
# action : [3]
# final state: [0]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [3]
# action : [3]
# state : [3]
# action : [3]
# state : [0]
# action : [0]
# final state: [0]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [1]
# action : [1]
# state : [0]
# action : [0]
# state : [1]
# action : [1]
# final state: [1]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [1]
# action : [1]
# state : [1]
# action : [1]
# state : [2]
# action : [2]
# final state: [2]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [3]
# action : [3]
# state : [3]
# action : [3]
# state : [3]
# action : [3]
# final state: [3]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [1]
# action : [1]
# state : [0]
# action : [0]
# state : [0]
# action : [0]
# final state: [3]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [3]
# action : [3]
# state : [3]
# action : [3]
# state : [3]
# action : [3]
# final state: [0]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [1]
# action : [1]
# final state: [0]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [0]
# action : [0]
# state : [0]
# action : [0]
# state : [0]
# action : [0]
# final state: [2]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [0]
# action : [0]
# state : [2]
# action : [2]
# final state: [0]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [3]
# action : [3]
# state : [0]
# action : [0]
# final state: [1]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [0]
# action : [0]
# state : [0]
# action : [0]
# state : [1]
# action : [1]
# final state: [0]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [1]
# action : [1]
# final state: [2]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [2]
# action : [2]
# final state: [1]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [0]
# action : [0]
# state : [3]
# action : [3]
# state : [3]
# action : [3]
# final state: [3]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [3]
# action : [3]
# state : [3]
# action : [3]
# state : [1]
# action : [1]
# final state: [1]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [1]
# action : [1]
# state : [0]
# action : [0]
# final state: [3]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [3]
# action : [3]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# final state: [3]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# final state: [0]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [1]
# action : [1]
# state : [3]
# action : [3]
# state : [1]
# action : [1]
# final state: [1]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [0]
# action : [0]
# final state: [3]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [0]
# action : [0]
# state : [0]
# action : [0]
# state : [3]
# action : [3]
# final state: [3]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [3]
# action : [3]
# state : [3]
# action : [3]
# state : [1]
# action : [1]
# final state: [1]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [0]
# action : [0]
# state : [1]
# action : [1]
# final state: [0]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [3]
# action : [3]
# final state: [0]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [1]
# action : [1]
# state : [0]
# action : [0]
# state : [0]
# action : [0]
# final state: [3]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [0]
# action : [0]
# final state: [2]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [3]
# action : [3]
# state : [1]
# action : [1]
# state : [0]
# action : [0]
# final state: [3]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [3]
# action : [3]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# final state: [3]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# final state: [2]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# final state: [1]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [3]
# action : [3]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# final state: [2]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [0]
# action : [0]
# state : [0]
# action : [0]
# state : [2]
# action : [2]
# final state: [0]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# final state: [0]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [0]
# action : [0]
# state : [1]
# action : [1]
# final state: [2]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [3]
# action : [3]
# state : [3]
# action : [3]
# state : [3]
# action : [3]
# final state: [2]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [1]
# action : [1]
# final state: [2]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [1]
# action : [1]
# state : [3]
# action : [3]
# final state: [3]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [1]
# action : [1]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# final state: [0]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [1]
# action : [1]
# state : [3]
# action : [3]
# state : [0]
# action : [0]
# final state: [0]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [0]
# action : [0]
# final state: [2]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [1]
# action : [1]
# state : [1]
# action : [1]
# state : [2]
# action : [2]
# final state: [2]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [3]
# action : [3]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# final state: [1]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [0]
# action : [0]
# state : [3]
# action : [3]
# state : [1]
# action : [1]
# final state: [2]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [0]
# action : [0]
# state : [2]
# action : [2]
# final state: [3]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [3]
# action : [3]
# state : [1]
# action : [1]
# final state: [3]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [0]
# action : [0]
# state : [3]
# action : [3]
# final state: [2]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [1]
# action : [1]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# final state: [2]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [1]
# action : [1]
# state : [0]
# action : [0]
# state : [3]
# action : [3]
# final state: [3]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [2]
# action : [2]
# final state: [1]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [1]
# action : [1]
# state : [3]
# action : [3]
# final state: [3]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [3]
# action : [3]
# state : [3]
# action : [3]
# final state: [3]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [3]
# action : [3]
# state : [0]
# action : [0]
# state : [2]
# action : [2]
# final state: [2]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [3]
# action : [3]
# state : [3]
# action : [3]
# final state: [2]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [0]
# action : [0]
# state : [0]
# action : [0]
# state : [0]
# action : [0]
# final state: [0]
# state : [2]
# action : [2]
# ...
# action : [3]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [0]
# action : [0]
# final state: [1]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [1]
# action : [1]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# final state: [0]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [3]
# action : [3]
# state : [0]
# action : [0]
# state : [2]
# action : [2]
# final state: [3]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [0]
# action : [0]
# final state: [1]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [3]
# action : [3]
# state : [1]
# action : [1]
# state : [2]
# action : [2]
# final state: [0]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [1]
# action : [1]
# state : [2]
# action : [2]
# final state: [0]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [1]
# action : [1]
# final state: [1]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [0]
# action : [0]
# state : [0]
# action : [0]
# state : [1]
# action : [1]
# final state: [2]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [3]
# action : [3]
# state : [3]
# action : [3]
# state : [1]
# action : [1]
# final state: [3]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [0]
# action : [0]
# state : [0]
# action : [0]
# final state: [0]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [0]
# action : [0]
# state : [1]
# action : [1]
# final state: [3]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [3]
# action : [3]
# state : [1]
# action : [1]
# state : [3]
# action : [3]
# final state: [3]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [1]
# action : [1]
# state : [2]
# action : [2]
# final state: [1]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [0]
# action : [0]
# state : [0]
# action : [0]
# state : [1]
# action : [1]
# final state: [3]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [0]
# action : [0]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# final state: [0]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [0]
# action : [0]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# final state: [0]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [1]
# action : [1]
# state : [1]
# action : [1]
# state : [3]
# action : [3]
# final state: [2]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [1]
# action : [1]
# state : [3]
# action : [3]
# state : [3]
# action : [3]
# final state: [1]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [0]
# action : [0]
# state : [1]
# action : [1]
# state : [1]
# action : [1]
# final state: [2]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [0]
# action : [0]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# final state: [3]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [0]
# action : [0]
# final state: [0]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# final state: [1]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [1]
# action : [1]
# state : [0]
# action : [0]
# state : [2]
# action : [2]
# final state: [2]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [0]
# action : [0]
# state : [3]
# action : [3]
# state : [3]
# action : [3]
# final state: [3]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [2]
# action : [2]
# final state: [2]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [1]
# action : [1]
# state : [0]
# action : [0]
# state : [0]
# action : [0]
# final state: [3]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [3]
# action : [3]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# final state: [3]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [3]
# action : [3]
# state : [0]
# action : [0]
# state : [0]
# action : [0]
# final state: [0]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [1]
# action : [1]
# state : [0]
# action : [0]
# state : [2]
# action : [2]
# final state: [1]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# final state: [2]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# final state: [1]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [1]
# action : [1]
# state : [0]
# action : [0]
# state : [3]
# action : [3]
# final state: [3]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [0]
# action : [0]
# final state: [3]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [0]
# action : [0]
# state : [1]
# action : [1]
# final state: [3]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [0]
# action : [0]
# state : [3]
# action : [3]
# state : [2]
# action : [2]
# final state: [3]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [3]
# action : [3]
# state : [1]
# action : [1]
# state : [2]
# action : [2]
# final state: [3]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [0]
# action : [0]
# state : [1]
# action : [1]
# state : [3]
# action : [3]
# final state: [3]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [0]
# action : [0]
# state : [3]
# action : [3]
# state : [3]
# action : [3]
# final state: [2]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [3]
# action : [3]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# final state: [3]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [0]
# action : [0]
# state : [0]
# action : [0]
# state : [3]
# action : [3]
# final state: [0]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [0]
# action : [0]
# state : [1]
# action : [1]
# state : [1]
# action : [1]
# final state: [3]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# final state: [0]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [3]
# action : [3]
# final state: [3]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [0]
# action : [0]
# state : [0]
# action : [0]
# state : [1]
# action : [1]
# final state: [3]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [3]
# action : [3]
# final state: [0]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [0]
# action : [0]
# state : [1]
# action : [1]
# state : [2]
# action : [2]
# final state: [2]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [3]
# action : [3]
# state : [0]
# action : [0]
# state : [2]
# action : [2]
# final state: [2]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [1]
# action : [1]
# state : [1]
# action : [1]
# state : [3]
# action : [3]
# final state: [1]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [1]
# action : [1]
# state : [3]
# action : [3]
# final state: [0]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [0]
# action : [0]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# final state: [2]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [1]
# action : [1]
# state : [3]
# action : [3]
# state : [2]
# action : [2]
# final state: [0]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [3]
# action : [3]
# state : [0]
# action : [0]
# state : [3]
# action : [3]
# final state: [0]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [1]
# action : [1]
# final state: [1]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [1]
# action : [1]
# state : [1]
# action : [1]
# state : [3]
# action : [3]
# final state: [0]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [3]
# action : [3]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# final state: [1]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [3]
# action : [3]
# state : [0]
# action : [0]
# state : [2]
# action : [2]
# final state: [1]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [3]
# action : [3]
# state : [1]
# action : [1]
# state : [0]
# action : [0]
# final state: [2]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [1]
# action : [1]
# state : [3]
# action : [3]
# state : [2]
# action : [2]
# final state: [2]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [1]
# action : [1]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# final state: [2]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# final state: [0]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [3]
# action : [3]
# state : [0]
# action : [0]
# state : [0]
# action : [0]
# final state: [3]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [2]
# action : [2]
# final state: [3]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# final state: [2]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [0]
# action : [0]
# state : [3]
# action : [3]
# state : [0]
# action : [0]
# final state: [2]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [0]
# action : [0]
# state : [0]
# action : [0]
# final state: [3]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [0]
# action : [0]
# state : [1]
# action : [1]
# state : [0]
# action : [0]
# final state: [1]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# final state: [2]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [0]
# action : [0]
# state : [0]
# action : [0]
# state : [3]
# action : [3]
# final state: [1]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [3]
# action : [3]
# state : [2]
# action : [2]
# final state: [1]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [0]
# action : [0]
# state : [1]
# action : [1]
# state : [1]
# action : [1]
# final state: [1]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [1]
# action : [1]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# final state: [0]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [3]
# action : [3]
# state : [3]
# action : [3]
# state : [3]
# action : [3]
# final state: [1]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [3]
# action : [3]
# state : [0]
# action : [0]
# final state: [2]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [1]
# action : [1]
# state : [3]
# action : [3]
# state : [2]
# action : [2]
# final state: [0]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [1]
# action : [1]
# final state: [2]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [1]
# action : [1]
# state : [0]
# action : [0]
# final state: [0]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [0]
# action : [0]
# state : [1]
# action : [1]
# state : [2]
# action : [2]
# final state: [2]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [1]
# action : [1]
# state : [0]
# action : [0]
# state : [1]
# action : [1]
# final state: [1]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# final state: [3]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [3]
# action : [3]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# final state: [1]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [1]
# action : [1]
# state : [0]
# action : [0]
# state : [2]
# action : [2]
# final state: [3]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [3]
# action : [3]
# state : [3]
# action : [3]
# final state: [2]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [1]
# action : [1]
# final state: [3]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [0]
# action : [0]
# state : [3]
# action : [3]
# state : [0]
# action : [0]
# final state: [2]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [0]
# action : [0]
# state : [3]
# action : [3]
# final state: [1]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [0]
# action : [0]
# state : [0]
# action : [0]
# state : [1]
# action : [1]
# final state: [3]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [0]
# action : [0]
# final state: [3]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [2]
# action : [2]
# final state: [0]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [3]
# action : [3]
# state : [2]
# action : [2]
# final state: [0]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# final state: [3]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [1]
# action : [1]
# state : [0]
# action : [0]
# state : [1]
# action : [1]
# final state: [2]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [3]
# action : [3]
# state : [0]
# action : [0]
# state : [2]
# action : [2]
# final state: [0]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [1]
# action : [1]
# state : [1]
# action : [1]
# state : [3]
# action : [3]
# final state: [3]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [2]
# action : [2]
# final state: [2]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [1]
# action : [1]
# state : [0]
# action : [0]
# state : [0]
# action : [0]
# final state: [1]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [1]
# action : [1]
# final state: [3]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [0]
# action : [0]
# final state: [1]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [1]
# action : [1]
# final state: [2]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [3]
# action : [3]
# final state: [1]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [0]
# action : [0]
# state : [0]
# action : [0]
# state : [2]
# action : [2]
# final state: [3]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# final state: [2]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# final state: [1]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [0]
# action : [0]
# state : [0]
# action : [0]
# state : [1]
# action : [1]
# final state: [3]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [1]
# action : [1]
# state : [3]
# action : [3]
# state : [1]
# action : [1]
# final state: [0]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# final state: [1]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [1]
# action : [1]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# final state: [0]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [3]
# action : [3]
# state : [1]
# action : [1]
# state : [2]
# action : [2]
# final state: [0]
# state : [2]
# action : [2]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [3]
# action : [3]
# state : [0]
# action : [0]
# final state: [0]
# state : [2]
# action : [2]
# state : [1]
# action : [1]
# state : [0]
# action : [0]
# state : [0]
# action : [0]
# state : [3]
# action : [3]
# final state: [3]
# state : [2]
# action : [2]
# state : [0]
# action : [0]
# state : [3]
# action : [3]
# state : [1]
# action : [1]
# state : [1]
# action : [1]
# final state: [2]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [0]
# action : [0]
# state : [1]
# action : [1]
# state : [1]
# action : [1]
# final state: [1]
# state : [2]
# action : [2]
# state : [3]
# action : [3]
# state : [1]
# action : [1]
# state : [1]
# action : [1]
# state : [3]
# action : [3]
# final state: [0]
# **************************************************
# Experiment complete
# **************************************************
