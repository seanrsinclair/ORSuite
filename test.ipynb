# %%
import or_suite

# %%
env = or_suite.envs.ambulance.ambulance_graph.AmbulanceGraphEnvironment()
agent = or_suite.agents.ambulance.stable.stableAgent(5)

dictionary = {'seed': 1, 'epFreq' : 1, 'targetPath': './tmp.csv', 'deBug' : False, 'nEps': 1000, 'recFreq' : 10, 'numIters' : 5, 'epLen': 5, 'saveTrajectory':False}

exp = or_suite.experiment.Experiment(env, agent, dictionary)
exp.run()
# Out:
# **************************************************
# Running experiment
# **************************************************
# **************************************************
# Experiment complete
# **************************************************

# %%
exp.save_data('./data', 'data.csv')
# Out:
# **************************************************
# Saving data
# **************************************************
# [[ 0.00000000e+00  0.00000000e+00 -9.00000000e+00  1.13100000e+03
#    9.25302505e+05]
#  [ 1.00000000e+00  0.00000000e+00 -6.00000000e+00  1.07500000e+03
#    8.75949860e+05]
#  [ 2.00000000e+00  0.00000000e+00 -1.05000000e+01  9.23000000e+02
#    8.31127167e+05]
#  ...
#  [ 9.97000000e+02  4.00000000e+00 -7.50000000e+00  6.71000000e+02
#    4.06980515e+05]
#  [ 9.98000000e+02  4.00000000e+00 -5.25000000e+00  6.71000000e+02
#    4.07457352e+05]
#  [ 9.99000000e+02  4.00000000e+00 -6.00000000e+00  6.71000000e+02
#    4.07457352e+05]]
# Writing to file data.csv
# **************************************************
# Data save complete
# **************************************************
#       episode  iteration  epReward  memory           time
# 0         0.0        0.0     -9.00  1131.0  925302.505493
# 1         1.0        0.0     -6.00  1075.0  875949.859619
# 2         2.0        0.0    -10.50   923.0  831127.166748
# 3         3.0        0.0     -7.50  1123.0  938415.527344
# 4         4.0        0.0     -9.00   923.0  722885.131836
# ...       ...        ...       ...     ...            ...
# 4995    995.0        4.0     -6.00   671.0  395298.004150
# 4996    996.0        4.0     -4.50   671.0  410079.956055
# 4997    997.0        4.0     -7.50   671.0  406980.514526
# 4998    998.0        4.0     -5.25   671.0  407457.351685
# 4999    999.0        4.0     -6.00   671.0  407457.351685
#
# [5000 rows x 5 columns]
